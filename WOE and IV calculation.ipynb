# %%
import os
import pandas as pd
import numpy as np
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string

max_bin = 20
force_bin = 3

# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
df = pd.read_csv("dtrain.csv")

# %%
final_iv, IV = data_vars(df,df["TARGET"])
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log

# %%
final_iv
# Out:
#                                   VAR_NAME      MIN_VALUE     MAX_VALUE  \
# 0        BUREAU_MICROLOAN_DAYS_CREDIT_MEAN   -1506.000000 -3.580000e+02
# 1        BUREAU_MICROLOAN_DAYS_CREDIT_MEAN    -357.000000 -1.810000e+02
# 2        BUREAU_MICROLOAN_DAYS_CREDIT_MEAN    -180.000000 -1.118000e+02
# 3        BUREAU_MICROLOAN_DAYS_CREDIT_MEAN    -111.560000 -6.800000e+01
# 4        BUREAU_MICROLOAN_DAYS_CREDIT_MEAN     -67.750000 -3.566000e+01
# 5        BUREAU_MICROLOAN_DAYS_CREDIT_MEAN     -35.500000 -1.000000e+00
# 6        BUREAU_MICROLOAN_DAYS_CREDIT_MEAN            NaN           NaN
# 7              CC_CNT_DRAWINGS_CURRENT_MAX       0.000000  1.000000e+00
# 8              CC_CNT_DRAWINGS_CURRENT_MAX       2.000000  6.000000e+00
# 9              CC_CNT_DRAWINGS_CURRENT_MAX       7.000000  1.650000e+02
# 10             CC_CNT_DRAWINGS_CURRENT_MAX            NaN           NaN
# 11          PREV_Cash_SIMPLE_INTERESTS_MAX       0.006720  1.456000e-02
# 12          PREV_Cash_SIMPLE_INTERESTS_MAX       0.014565  1.913000e-02
# 13          PREV_Cash_SIMPLE_INTERESTS_MAX       0.019150  2.394000e-02
# 14          PREV_Cash_SIMPLE_INTERESTS_MAX       0.023960  2.791000e-02
# 15          PREV_Cash_SIMPLE_INTERESTS_MAX       0.027920  3.534000e-02
# 16          PREV_Cash_SIMPLE_INTERESTS_MAX       0.035400  4.460000e-02
# 17          PREV_Cash_SIMPLE_INTERESTS_MAX            NaN           NaN
# 18   INS_48M_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.000000  6.250000e-02
# 19   INS_48M_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.063200  2.708000e-01
# 20   INS_48M_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.271200  7.314000e-01
# 21   INS_48M_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.732000  3.500000e+01
# 22   INS_48M_CNT_DRAWINGS_ATM_CURRENT_MEAN            NaN           NaN
# 23        CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.000000  6.250000e-02
# 24        CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.063200  2.708000e-01
# 25        CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.271200  7.314000e-01
# 26        CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.732000  3.500000e+01
# 27        CC_CNT_DRAWINGS_ATM_CURRENT_MEAN            NaN           NaN
# 28   INS_24M_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.000000  6.250000e-02
# 29   INS_24M_CNT_DRAWINGS_ATM_CURRENT_MEAN       0.063200  2.708000e-01
# ..                                     ...            ...           ...
# 288                             AMT_CREDIT  513693.000000  4.050000e+06
# 289                  CREDIT_INCOME_PERCENT       0.037500  3.265067e+00
# 290                  CREDIT_INCOME_PERCENT       3.265306  8.473684e+01
# 291                 ANNUITY_INCOME_PERCENT       0.003333  1.147842e-01
# 292                 ANNUITY_INCOME_PERCENT       0.114785  1.628333e-01
# 293                 ANNUITY_INCOME_PERCENT       0.162837  2.290667e-01
# 294                 ANNUITY_INCOME_PERCENT       0.229071  1.875965e+00
# 295                 ANNUITY_INCOME_PERCENT            NaN           NaN
# 296                            CREDIT_TERM       0.022073  4.236634e-02
# 297                            CREDIT_TERM       0.042366  5.444000e-02
# 298                            CREDIT_TERM       0.054440  1.244296e-01
# 299                            CREDIT_TERM            NaN           NaN
# 300                  DAYS_EMPLOYED_PERCENT      -0.000000  3.793049e-02
# 301                  DAYS_EMPLOYED_PERCENT       0.037932  7.501019e-02
# 302                  DAYS_EMPLOYED_PERCENT       0.075011  1.187319e-01
# 303                  DAYS_EMPLOYED_PERCENT       0.118733  1.783762e-01
# 304                  DAYS_EMPLOYED_PERCENT       0.178377  2.748907e-01
# 305                  DAYS_EMPLOYED_PERCENT       0.274892  7.291370e-01
# 306                  DAYS_EMPLOYED_PERCENT            NaN           NaN
# 307                      DAYS_REGISTRATION  -24670.000000 -7.480000e+03
# 308                      DAYS_REGISTRATION   -7476.000000 -4.504000e+03
# 309                      DAYS_REGISTRATION   -4500.000000 -2.010000e+03
# 310                      DAYS_REGISTRATION   -2009.000000  0.000000e+00
# 311                       AMT_INCOME_TOTAL   25650.000000  1.471500e+05
# 312                       AMT_INCOME_TOTAL  147447.000000  1.800009e+07
# 313                        AMT_GOODS_PRICE   40500.000000  4.500000e+05
# 314                        AMT_GOODS_PRICE  450234.000000  4.050000e+06
# 315                        AMT_GOODS_PRICE            NaN           NaN
# 316                             SK_ID_CURR  100002.000000  2.782030e+05
# 317                             SK_ID_CURR  278204.000000  4.562550e+05
#
#       COUNT    EVENT  EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  \
# 0       586     76.0    0.129693     510.0        0.870307    0.003062
# 1       583    101.0    0.173242     482.0        0.826758    0.004069
# 2       582    115.0    0.197595     467.0        0.802405    0.004633
# 3       588    126.0    0.214286     462.0        0.785714    0.005076
# 4       578    130.0    0.224913     448.0        0.775087    0.005237
# 5       582    154.0    0.264605     428.0        0.735395    0.006204
# 6    304007  24122.0    0.079347  279885.0        0.920653    0.971721
# 7     31670   1745.0    0.055099   29925.0        0.944901    0.070295
# 8     28078   2248.0    0.080063   25830.0        0.919937    0.090558
# 9     27157   3541.0    0.130390   23616.0        0.869610    0.142644
# 10   220601  17290.0    0.078377  203311.0        0.921623    0.696503
# 11    24881   1328.0    0.053374   23553.0        0.946626    0.053497
# 12    25718   1509.0    0.058675   24209.0        0.941325    0.060788
# 13    24223   1767.0    0.072947   22456.0        0.927053    0.071181
# 14    24778   2173.0    0.087699   22605.0        0.912301    0.087536
# 15    27592   2742.0    0.099377   24850.0        0.900623    0.110458
# 16    22005   3082.0    0.140059   18923.0        0.859941    0.124154
# 17   158309  12223.0    0.077210  146086.0        0.922790    0.492386
# 18    15285   1046.0    0.068433   14239.0        0.931567    0.042137
# 19    15312   1115.0    0.072819   14197.0        0.927181    0.044916
# 20    15259   1584.0    0.103808   13675.0        0.896192    0.063809
# 21    15284   2396.0    0.156765   12888.0        0.843235    0.096519
# 22   246366  18683.0    0.075834  227683.0        0.924166    0.752618
# 23    15285   1046.0    0.068433   14239.0        0.931567    0.042137
# 24    15312   1115.0    0.072819   14197.0        0.927181    0.044916
# 25    15259   1584.0    0.103808   13675.0        0.896192    0.063809
# 28         0.050371 -0.178500  0.048115
# 29         0.050223 -0.111665  0.048115
# ..              ...       ...       ...
# 288        0.501694 -0.050563  0.002449
# 289        0.499926  0.002482  0.000006
# 290        0.500074 -0.002488  0.000006
# 291        0.252114 -0.110098  0.005162
# 292        0.250550 -0.026170  0.005162
# 293        0.248689  0.061035  0.005162
# 294        0.248604  0.066696  0.005162
# 295        0.000042  0.000000  0.005162
# 296        0.338801 -0.218298  0.021004
# 297        0.331181  0.082135  0.021004
# 298        0.329975  0.109369  0.021004
# 299        0.000042  0.000000  0.021004
# 300        0.132722  0.312657  0.087921
# 301        0.132771  0.309170  0.087921
# 302        0.134243  0.200920  0.087921
# 303        0.136132  0.046448  0.087921
# 304        0.138254 -0.154741  0.087921
# 305        0.140568 -0.422942  0.087921
# 306        0.185311 -0.430816  0.087921
# 307        0.254954 -0.268019  0.022748
# 308        0.249952  0.008855  0.022748
# 309        0.247954  0.086153  0.022748
# 310        0.247140  0.133898  0.022748
# 311        0.498012  0.048730  0.002475
# 312        0.501988 -0.050811  0.002475
# 313        0.506127  0.170719  0.036047
# 314        0.492964 -0.211957  0.036047
# 315        0.000909 -0.072042  0.036047
# 316        0.499547  0.011166  0.000126
# 317        0.500453 -0.011271  0.000126
#
# [318 rows x 12 columns]

# %%
IV.sort_values('IV')
# Out:
#                                  VAR_NAME        IV
# 9                   CREDIT_INCOME_PERCENT  0.000006
# 33                             SK_ID_CURR  0.000126
# 0                             AMT_ANNUITY  0.000495
# 1                              AMT_CREDIT  0.002449
# 3                        AMT_INCOME_TOTAL  0.002475
# 4                  ANNUITY_INCOME_PERCENT  0.005162
# 10                            CREDIT_TERM  0.021004
# 5       BUREAU_MICROLOAN_DAYS_CREDIT_MEAN  0.021017
# 14                      DAYS_REGISTRATION  0.022748
# 2                         AMT_GOODS_PRICE  0.036047
# 7             CC_CNT_DRAWINGS_CURRENT_MAX  0.046917
# 6        CC_CNT_DRAWINGS_ATM_CURRENT_MEAN  0.048115
# 29  INS_48M_CNT_DRAWINGS_ATM_CURRENT_MEAN  0.048115
# 27  INS_24M_CNT_DRAWINGS_ATM_CURRENT_MEAN  0.048115
# 25  INS_12M_CNT_DRAWINGS_ATM_CURRENT_MEAN  0.048115
# 8                       CC_LIMIT_USE_MEAN  0.060650
# 28                 INS_24M_LIMIT_USE_MEAN  0.060650
# 26                 INS_12M_LIMIT_USE_MEAN  0.060650
# 30                 INS_48M_LIMIT_USE_MEAN  0.060650
# 31         PREV_Cash_SIMPLE_INTERESTS_MAX  0.064994
# 32        PREV_Cash_SIMPLE_INTERESTS_MEAN  0.073420
# 11                             DAYS_BIRTH  0.084913
# 13                  DAYS_EMPLOYED_PERCENT  0.087921
# 12                          DAYS_EMPLOYED  0.109393
# 24               GROUP_EXT_SOURCES_MEDIAN  0.117577
# 21                           EXT_SOURCE_1  0.155330
# 20                   EXT_SOURCES_WEIGHTED  0.266658
# 19                       EXT_SOURCES_PROD  0.273734
# 22                           EXT_SOURCE_2  0.318501
# 23                           EXT_SOURCE_3  0.336065
# 15                        EXT_SOURCES_MAX  0.450997
# 17                        EXT_SOURCES_MIN  0.476719
# 18                  EXT_SOURCES_NANMEDIAN  0.594739
# 16                       EXT_SOURCES_MEAN  0.622732

# %%
final_iv.to_excel("IV_groups.xlsx")

# %%
IV.to_excel("iv.xlsx")
